# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 616

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
base_url = "http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=" + weather_api_key
# query_url = base_url + "&appid=" + weather_api_key + "&q="


# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

#Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = base_url + "&q=" + city #city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
#6.2.6
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
#         city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country })
#                           "Date": city_date})
    
    # If an error is experienced, skip the city
    except:
        print(f'City not found. Skipping...')
        pass


              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | jamestown
# Processing Record 2 of Set 1 | san patricio
# Processing Record 3 of Set 1 | ordos
# City not found. Skipping...
# Processing Record 4 of Set 1 | waitangi
# Processing Record 5 of Set 1 | grytviken
# Processing Record 6 of Set 1 | port-aux-francais
# Processing Record 7 of Set 1 | linhares
# Processing Record 8 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 9 of Set 1 | tiksi
# Processing Record 10 of Set 1 | mil'kovo
# Processing Record 11 of Set 1 | santa eularia des riu
# Processing Record 12 of Set 1 | college
# Processing Record 13 of Set 1 | vilyuchinsk
# Processing Record 14 of Set 1 | kilosa
# Processing Record 15 of Set 1 | 'ohonua
# City not found. Skipping...
# Processing Record 16 of Set 1 | port elizabeth
# Processing Record 17 of Set 1 | adamstown
# Processing Record 18 of Set 1 | katabu
# Processing Record 19 of Set 1 | atafu village
# Processing Record 20 of Set 1 | karwar
# Processing Record 21 of Set 1 | tazacorte
# Processing Record 22 of Set 1 | naze
# Processing Record 23 of Set 1 | piti village
# Processing Record 24 of Set 1 | bethel
# Processing Record 25 of Set 1 | invercargill
# Processing Record 26 of Set 1 | chiang rai
# Processing Record 27 of Set 1 | edinburgh of the seven seas
# Processing Record 28 of Set 1 | touros
# Processing Record 29 of Set 1 | anqing
# Processing Record 30 of Set 1 | turkmenbasy
# Processing Record 31 of Set 1 | jiwani
# Processing Record 32 of Set 1 | ribeira grande
# Processing Record 33 of Set 1 | magadan
# Processing Record 34 of Set 1 | iskateley
# Processing Record 35 of Set 1 | iqaluit
# Processing Record 36 of Set 1 | alaghsas
# Processing Record 37 of Set 1 | mandalgovi
# Processing Record 38 of Set 1 | talnakh
# Processing Record 39 of Set 1 | gweru
# Processing Record 40 of Set 1 | hawaiian paradise park
# Processing Record 41 of Set 1 | nar'yan-mar
# Processing Record 42 of Set 1 | petoskey
# Processing Record 43 of Set 1 | tual
# Processing Record 44 of Set 1 | san antonio de pale
# Processing Record 45 of Set 1 | puerto natales
# Processing Record 46 of Set 1 | lardjem
# Processing Record 47 of Set 1 | olonkinbyen
# Processing Record 48 of Set 1 | el calafate
# Processing Record 49 of Set 1 | palmer
# Processing Record 50 of Set 1 | albany
# Processing Record 1 of Set 2 | port shepstone
# Processing Record 2 of Set 2 | paita
# Processing Record 3 of Set 2 | turabah
# Processing Record 4 of Set 2 | daru
# Processing Record 5 of Set 2 | wailua homesteads
# Processing Record 6 of Set 2 | dolinsk
# Processing Record 7 of Set 2 | soverato marina
# Processing Record 8 of Set 2 | papatowai
# Processing Record 9 of Set 2 | tsiombe
# Processing Record 10 of Set 2 | klyuchi
# Processing Record 11 of Set 2 | saynshand
# Processing Record 12 of Set 2 | egilsstadir
# Processing Record 13 of Set 2 | brigantine
# Processing Record 14 of Set 2 | whitehorse
# Processing Record 15 of Set 2 | hermanus
# Processing Record 16 of Set 2 | kodiak
# Processing Record 17 of Set 2 | afaahiti
# Processing Record 18 of Set 2 | margate
# Processing Record 19 of Set 2 | kingston
# Processing Record 20 of Set 2 | puerto ayora
# Processing Record 21 of Set 2 | kurumkan
# Processing Record 22 of Set 2 | nema
# Processing Record 23 of Set 2 | rockingham
# Processing Record 24 of Set 2 | baytown
# Processing Record 25 of Set 2 | diego de almagro
# Processing Record 26 of Set 2 | sinop
# Processing Record 27 of Set 2 | trenggalek
# Processing Record 28 of Set 2 | dossor
# Processing Record 29 of Set 2 | hammerfest
# Processing Record 30 of Set 2 | mount pearl
# Processing Record 31 of Set 2 | ketchikan
# Processing Record 32 of Set 2 | bredasdorp
# Processing Record 33 of Set 2 | margaret river
# Processing Record 34 of Set 2 | qasr-e qand
# City not found. Skipping...
# Processing Record 35 of Set 2 | badger
# Processing Record 36 of Set 2 | fale old settlement
# Processing Record 37 of Set 2 | international falls
# Processing Record 38 of Set 2 | bulungu
# Processing Record 39 of Set 2 | anadyr
# Processing Record 40 of Set 2 | saipan
# Processing Record 41 of Set 2 | saint-francois
# Processing Record 42 of Set 2 | tanjung selor
# City not found. Skipping...
# Processing Record 43 of Set 2 | kailua-kona
# Processing Record 44 of Set 2 | xilin hot
# Processing Record 45 of Set 2 | enewetak
# Processing Record 46 of Set 2 | acapulco de juarez
# Processing Record 47 of Set 2 | keflavik
# Processing Record 48 of Set 2 | monrovia
# Processing Record 49 of Set 2 | chibougamau
# Processing Record 50 of Set 2 | west island
# Processing Record 1 of Set 3 | remire-montjoly
# Processing Record 2 of Set 3 | lesozavodsk
# Processing Record 3 of Set 3 | susuman
# Processing Record 4 of Set 3 | yellowknife
# Processing Record 5 of Set 3 | kununurra
# Processing Record 6 of Set 3 | taltal
# Processing Record 7 of Set 3 | qaqortoq
# Processing Record 8 of Set 3 | isafjordur
# Processing Record 9 of Set 3 | tura
# Processing Record 10 of Set 3 | ust-nera
# Processing Record 11 of Set 3 | visby
# Processing Record 12 of Set 3 | zaozersk
# Processing Record 13 of Set 3 | sastre
# Processing Record 14 of Set 3 | porto velho
# Processing Record 15 of Set 3 | luynes
# Processing Record 16 of Set 3 | pangoa
# Processing Record 17 of Set 3 | longyearbyen
# Processing Record 18 of Set 3 | hithadhoo
# Processing Record 19 of Set 3 | utrik
# Processing Record 20 of Set 3 | avarua
# Processing Record 21 of Set 3 | crane
# Processing Record 22 of Set 3 | bojnurd
# Processing Record 23 of Set 3 | cuamba
# Processing Record 24 of Set 3 | barroso
# Processing Record 25 of Set 3 | blackmans bay
# Processing Record 26 of Set 3 | chom bueng
# Processing Record 27 of Set 3 | kyelang
# Processing Record 28 of Set 3 | al marj
# Processing Record 29 of Set 3 | vila do maio
# Processing Record 30 of Set 3 | kone
# Processing Record 31 of Set 3 | masterton
# Processing Record 32 of Set 3 | greenville
# Processing Record 33 of Set 3 | severnoye
# Processing Record 34 of Set 3 | ponta delgada
# Processing Record 35 of Set 3 | tobi village
# City not found. Skipping...
# Processing Record 36 of Set 3 | shingu
# Processing Record 37 of Set 3 | new norfolk
# Processing Record 38 of Set 3 | ilulissat
# Processing Record 39 of Set 3 | saudarkrokur
# Processing Record 40 of Set 3 | stanley
# Processing Record 41 of Set 3 | preobrazheniye
# Processing Record 42 of Set 3 | inhambane
# Processing Record 43 of Set 3 | kayangel
# Processing Record 44 of Set 3 | argo
# Processing Record 45 of Set 3 | prado
# Processing Record 46 of Set 3 | floro
# Processing Record 47 of Set 3 | tippi
# Processing Record 48 of Set 3 | tranovaho
# City not found. Skipping...
# Processing Record 49 of Set 3 | novyy urengoy
# Processing Record 50 of Set 3 | khadan khak
# Processing Record 1 of Set 4 | rio grande
# Processing Record 2 of Set 4 | happy valley-goose bay
# Processing Record 3 of Set 4 | alofi
# Processing Record 4 of Set 4 | koupela
# Processing Record 5 of Set 4 | alotau
# City not found. Skipping...
# Processing Record 6 of Set 4 | buri ram
# Processing Record 7 of Set 4 | cabo san lucas
# Processing Record 8 of Set 4 | dudinka
# Processing Record 9 of Set 4 | newman
# Processing Record 10 of Set 4 | thompson
# Processing Record 11 of Set 4 | griffith
# Processing Record 12 of Set 4 | nizhnedevitsk
# Processing Record 13 of Set 4 | salinas
# Processing Record 14 of Set 4 | kerikeri
# Processing Record 15 of Set 4 | bechar
# Processing Record 16 of Set 4 | araban
# Processing Record 17 of Set 4 | georgetown
# Processing Record 18 of Set 4 | acheng
# Processing Record 19 of Set 4 | adrar
# Processing Record 20 of Set 4 | haiku-pauwela
# Processing Record 21 of Set 4 | fiambala
# Processing Record 22 of Set 4 | arteche
# Processing Record 23 of Set 4 | vingt cinq
# City not found. Skipping...
# Processing Record 24 of Set 4 | sant'agata di militello
# Processing Record 25 of Set 4 | arlington
# Processing Record 26 of Set 4 | pangody
# Processing Record 27 of Set 4 | lihue
# Processing Record 28 of Set 4 | sitka
# Processing Record 29 of Set 4 | nova sintra
# Processing Record 30 of Set 4 | zabaykal'sk
# Processing Record 31 of Set 4 | rtishchevo
# Processing Record 32 of Set 4 | hilo
# Processing Record 33 of Set 4 | colby
# Processing Record 34 of Set 4 | zhoukou
# Processing Record 35 of Set 4 | kajiado
# Processing Record 36 of Set 4 | siwa oasis
# Processing Record 37 of Set 4 | gorontalo
# Processing Record 38 of Set 4 | bamboo flat
# Processing Record 39 of Set 4 | mount gambier
# Processing Record 40 of Set 4 | santa terezinha
# Processing Record 41 of Set 4 | pontes e lacerda
# Processing Record 42 of Set 4 | ushuaia
# Processing Record 43 of Set 4 | takamaka
# City not found. Skipping...
# Processing Record 44 of Set 4 | cox's bazar
# Processing Record 45 of Set 4 | sarandi del yi
# Processing Record 46 of Set 4 | bilibino
# Processing Record 47 of Set 4 | jinghong
# Processing Record 48 of Set 4 | umba
# Processing Record 49 of Set 4 | san julian
# Processing Record 50 of Set 4 | camacupa
# Processing Record 1 of Set 5 | hotan
# Processing Record 2 of Set 5 | west bay
# Processing Record 3 of Set 5 | ust'-uda
# Processing Record 4 of Set 5 | east london
# Processing Record 5 of Set 5 | bardai
# Processing Record 6 of Set 5 | uruacu
# Processing Record 7 of Set 5 | harnosand
# Processing Record 8 of Set 5 | lompoc
# Processing Record 9 of Set 5 | bam
# Processing Record 10 of Set 5 | kidal
# Processing Record 11 of Set 5 | fort bragg
# Processing Record 12 of Set 5 | rukban
# City not found. Skipping...
# Processing Record 13 of Set 5 | port saint john's
# Processing Record 14 of Set 5 | pundong
# Processing Record 15 of Set 5 | horta
# Processing Record 16 of Set 5 | port mathurin
# Processing Record 17 of Set 5 | chatra
# Processing Record 18 of Set 5 | denov
# Processing Record 19 of Set 5 | udachny
# Processing Record 20 of Set 5 | arraial do cabo
# Processing Record 21 of Set 5 | whangarei
# Processing Record 22 of Set 5 | kenai
# Processing Record 23 of Set 5 | bilaspur
# Processing Record 24 of Set 5 | sanya
# Processing Record 25 of Set 5 | dogubayazit
# Processing Record 26 of Set 5 | alice springs
# Processing Record 27 of Set 5 | yanbu
# Processing Record 28 of Set 5 | port lincoln
# Processing Record 29 of Set 5 | fuvahmulah
# City not found. Skipping...
# Processing Record 30 of Set 5 | hoxtolgay
# City not found. Skipping...
# Processing Record 31 of Set 5 | antonio enes
# Processing Record 32 of Set 5 | mhamid
# Processing Record 33 of Set 5 | crockett
# Processing Record 34 of Set 5 | tofol
# Processing Record 35 of Set 5 | wotje
# Processing Record 36 of Set 5 | bonthe
# Processing Record 37 of Set 5 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 38 of Set 5 | garoowe
# Processing Record 39 of Set 5 | espargos
# City not found. Skipping...
# Processing Record 40 of Set 5 | kosh-agach
# Processing Record 41 of Set 5 | usogorsk
# Processing Record 42 of Set 5 | mianyang
# Processing Record 43 of Set 5 | constantia
# Processing Record 44 of Set 5 | slave lake
# Processing Record 45 of Set 5 | revda
# Processing Record 46 of Set 5 | uturoa
# Processing Record 47 of Set 5 | farafangana
# Processing Record 48 of Set 5 | tuburan
# Processing Record 49 of Set 5 | paracatu
# Processing Record 50 of Set 5 | arvin
# Processing Record 1 of Set 6 | calca
# Processing Record 2 of Set 6 | cooma
# Processing Record 3 of Set 6 | clarence town
# Processing Record 4 of Set 6 | fortaleza
# Processing Record 5 of Set 6 | moss bluff
# Processing Record 6 of Set 6 | east end village
# City not found. Skipping...
# Processing Record 7 of Set 6 | nizip
# Processing Record 8 of Set 6 | dar naim
# City not found. Skipping...
# Processing Record 9 of Set 6 | conceicao do araguaia
# Processing Record 10 of Set 6 | el granada
# Processing Record 11 of Set 6 | novodvinsk
# Processing Record 12 of Set 6 | anamosa
# Processing Record 13 of Set 6 | puerto san carlos
# City not found. Skipping...
# Processing Record 14 of Set 6 | porto novo
# Processing Record 15 of Set 6 | maloye ganyushkino
# Processing Record 16 of Set 6 | coyhaique
# Processing Record 17 of Set 6 | cliza
# Processing Record 18 of Set 6 | singaraja
# Processing Record 19 of Set 6 | santo antonio
# Processing Record 20 of Set 6 | namibe
# Processing Record 21 of Set 6 | kalifornsky
# Processing Record 22 of Set 6 | gadzhiyevo
# Processing Record 23 of Set 6 | la passe
# Processing Record 24 of Set 6 | xique xique
# Processing Record 25 of Set 6 | salaqi
# Processing Record 26 of Set 6 | zhumysker
# Processing Record 27 of Set 6 | ta`u
# Processing Record 28 of Set 6 | cockburn town
# Processing Record 29 of Set 6 | nemuro
# Processing Record 30 of Set 6 | michurinsk
# Processing Record 31 of Set 6 | cidreira
# Processing Record 32 of Set 6 | machico
# Processing Record 33 of Set 6 | al hazm
# Processing Record 34 of Set 6 | zuunmod
# Processing Record 35 of Set 6 | hadibu
# Processing Record 36 of Set 6 | dauphin
# Processing Record 37 of Set 6 | el fasher
# Processing Record 38 of Set 6 | hasaki
# Processing Record 39 of Set 6 | kristiansund
# Processing Record 40 of Set 6 | smithers
# Processing Record 41 of Set 6 | polyarnyy
# Processing Record 42 of Set 6 | cut off
# Processing Record 43 of Set 6 | kapuskasing
# Processing Record 44 of Set 6 | angaur state
# Processing Record 45 of Set 6 | punta cana
# Processing Record 46 of Set 6 | talara
# Processing Record 47 of Set 6 | la romana
# Processing Record 48 of Set 6 | north bondi
# Processing Record 49 of Set 6 | brookings
# Processing Record 50 of Set 6 | santa maria
# Processing Record 1 of Set 7 | mount isa
# Processing Record 2 of Set 7 | marsabit
# Processing Record 3 of Set 7 | tolanaro
# Processing Record 4 of Set 7 | nyurba
# Processing Record 5 of Set 7 | veraval
# Processing Record 6 of Set 7 | waddan
# Processing Record 7 of Set 7 | tottori
# Processing Record 8 of Set 7 | yelizovo
# Processing Record 9 of Set 7 | gunjur
# Processing Record 10 of Set 7 | carnarvon
# Processing Record 11 of Set 7 | hot springs village
# Processing Record 12 of Set 7 | baltinava
# Processing Record 13 of Set 7 | abdulino
# Processing Record 14 of Set 7 | brainerd
# Processing Record 15 of Set 7 | fort st. john
# Processing Record 16 of Set 7 | qusmuryn
# Processing Record 17 of Set 7 | cerkes
# Processing Record 18 of Set 7 | mejit
# Processing Record 19 of Set 7 | salalah
# Processing Record 20 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 21 of Set 7 | chonchi
# Processing Record 22 of Set 7 | thisted
# Processing Record 23 of Set 7 | leua
# Processing Record 24 of Set 7 | konstantinovka
# Processing Record 25 of Set 7 | an nuhud
# Processing Record 26 of Set 7 | saint-philippe
# Processing Record 27 of Set 7 | bodo
# Processing Record 28 of Set 7 | aral
# Processing Record 29 of Set 7 | yermakovskoye
# Processing Record 30 of Set 7 | pontianak
# Processing Record 31 of Set 7 | santa marta
# Processing Record 32 of Set 7 | al khums
# Processing Record 33 of Set 7 | mangrol
# Processing Record 34 of Set 7 | cargados carajos
# City not found. Skipping...
# Processing Record 35 of Set 7 | ranau
# Processing Record 36 of Set 7 | walvis bay
# Processing Record 37 of Set 7 | gizo
# Processing Record 38 of Set 7 | sundargarh
# Processing Record 39 of Set 7 | pitimbu
# Processing Record 40 of Set 7 | ixtapa
# Processing Record 41 of Set 7 | lesnoy
# Processing Record 42 of Set 7 | sinan
# Processing Record 43 of Set 7 | boyolangu
# Processing Record 44 of Set 7 | hobyo
# Processing Record 45 of Set 7 | lianhe
# Processing Record 46 of Set 7 | queenstown
# Processing Record 47 of Set 7 | ulladulla
# Processing Record 48 of Set 7 | dukhan
# Processing Record 49 of Set 7 | nosy varika
# Processing Record 50 of Set 7 | cururupu
# Processing Record 1 of Set 8 | trondheim
# Processing Record 2 of Set 8 | st. john's
# Processing Record 3 of Set 8 | persembe
# Processing Record 4 of Set 8 | sittwe
# Processing Record 5 of Set 8 | mutuali
# Processing Record 6 of Set 8 | tchintabaraden
# Processing Record 7 of Set 8 | khenchela
# Processing Record 8 of Set 8 | linxia chengguanzhen
# Processing Record 9 of Set 8 | sosnovka
# Processing Record 10 of Set 8 | richards bay
# Processing Record 11 of Set 8 | pierre
# Processing Record 12 of Set 8 | juneau
# Processing Record 13 of Set 8 | kyabe
# Processing Record 14 of Set 8 | lata
# Processing Record 15 of Set 8 | manggar
# Processing Record 16 of Set 8 | east aurora
# Processing Record 17 of Set 8 | hamilton
# Processing Record 18 of Set 8 | aasiaat
# Processing Record 19 of Set 8 | sandur
# Processing Record 20 of Set 8 | tazovsky
# Processing Record 21 of Set 8 | boende
# Processing Record 22 of Set 8 | fabrica di roma
# Processing Record 23 of Set 8 | aswan
# Processing Record 24 of Set 8 | kruisfontein
# Processing Record 25 of Set 8 | soio
# Processing Record 26 of Set 8 | gaspe
# Processing Record 27 of Set 8 | galliano
# Processing Record 28 of Set 8 | santa ana
# Processing Record 29 of Set 8 | taitung city
# Processing Record 30 of Set 8 | cill airne
# Processing Record 31 of Set 8 | minas de marcona
# Processing Record 32 of Set 8 | masaurhi buzurg
# Processing Record 33 of Set 8 | ahau
# City not found. Skipping...
# Processing Record 34 of Set 8 | kombolcha
# Processing Record 35 of Set 8 | ntungamo
# Processing Record 36 of Set 8 | vryburg
# Processing Record 37 of Set 8 | stephenville
# Processing Record 38 of Set 8 | yamba
# Processing Record 39 of Set 8 | saint croix
# Processing Record 40 of Set 8 | tostado
# Processing Record 41 of Set 8 | suva
# Processing Record 42 of Set 8 | geraldton
# Processing Record 43 of Set 8 | broome
# Processing Record 44 of Set 8 | uvalde
# Processing Record 45 of Set 8 | hue
# Processing Record 46 of Set 8 | bosaso
# Processing Record 47 of Set 8 | terekeka
# City not found. Skipping...
# Processing Record 48 of Set 8 | nikolayevsk-on-amure
# Processing Record 49 of Set 8 | gutao
# Processing Record 50 of Set 8 | mpika
# Processing Record 1 of Set 9 | san pedro
# Processing Record 2 of Set 9 | kavaratti
# Processing Record 3 of Set 9 | codrington
# Processing Record 4 of Set 9 | nazyvayevsk
# Processing Record 5 of Set 9 | kostanay
# Processing Record 6 of Set 9 | wolmaransstad
# Processing Record 7 of Set 9 | henderson
# Processing Record 8 of Set 9 | olanchito
# Processing Record 9 of Set 9 | bir hadaj
# City not found. Skipping...
# Processing Record 10 of Set 9 | sungai penuh
# Processing Record 11 of Set 9 | igarka
# Processing Record 12 of Set 9 | kuqa
# Processing Record 13 of Set 9 | aykhal
# Processing Record 14 of Set 9 | nakhodka
# Processing Record 15 of Set 9 | ribeira brava
# Processing Record 16 of Set 9 | mana
# Processing Record 17 of Set 9 | naryn
# Processing Record 18 of Set 9 | guarapari
# Processing Record 19 of Set 9 | morehead city
# Processing Record 20 of Set 9 | martil
# Processing Record 21 of Set 9 | whitecourt
# Processing Record 22 of Set 9 | necochea
# Processing Record 23 of Set 9 | fredericton
# Processing Record 24 of Set 9 | karpinsk
# Processing Record 25 of Set 9 | rikaze
# Processing Record 26 of Set 9 | nagqu
# Processing Record 27 of Set 9 | hanceville
# Processing Record 28 of Set 9 | saldanha
# Processing Record 29 of Set 9 | mollerussa
# Processing Record 30 of Set 9 | sisimiut
# Processing Record 31 of Set 9 | as saffaniyah
# Processing Record 32 of Set 9 | malabar
# Processing Record 33 of Set 9 | trimbak
# Processing Record 34 of Set 9 | monte alegre
# Processing Record 35 of Set 9 | mwene-ditu
# Processing Record 36 of Set 9 | muleba
# Processing Record 37 of Set 9 | antsiranana
# Processing Record 38 of Set 9 | bereznik
# Processing Record 39 of Set 9 | bikenibeu village
# Processing Record 40 of Set 9 | san jose del cabo
# Processing Record 41 of Set 9 | valdivia
# Processing Record 42 of Set 9 | barcelos
# Processing Record 43 of Set 9 | galesong
# Processing Record 44 of Set 9 | moab
# Processing Record 45 of Set 9 | borazjan
# Processing Record 46 of Set 9 | harstad
# Processing Record 47 of Set 9 | puerto santa
# Processing Record 48 of Set 9 | karratha
# Processing Record 49 of Set 9 | pisco
# Processing Record 50 of Set 9 | floriano
# Processing Record 1 of Set 10 | labrador city
# Processing Record 2 of Set 10 | ouellah
# City not found. Skipping...
# Processing Record 3 of Set 10 | gornopravdinsk
# Processing Record 4 of Set 10 | jilib
# Processing Record 5 of Set 10 | molo
# Processing Record 6 of Set 10 | yei
# Processing Record 7 of Set 10 | punta arenas
# Processing Record 8 of Set 10 | pacific grove
# Processing Record 9 of Set 10 | pimentel
# Processing Record 10 of Set 10 | albu kamal
# Processing Record 11 of Set 10 | sur
# Processing Record 12 of Set 10 | vadso
# Processing Record 13 of Set 10 | diffa
# Processing Record 14 of Set 10 | khunti
# Processing Record 15 of Set 10 | motygino
# Processing Record 16 of Set 10 | kranuan
# Processing Record 17 of Set 10 | port douglas
# Processing Record 18 of Set 10 | coahuayana de hidalgo
# Processing Record 19 of Set 10 | new amsterdam
# Processing Record 20 of Set 10 | shimoda
# Processing Record 21 of Set 10 | paulden
# Processing Record 22 of Set 10 | altamont
# Processing Record 23 of Set 10 | livingston
# Processing Record 24 of Set 10 | mantua
# Processing Record 25 of Set 10 | devinuwara
# City not found. Skipping...
# Processing Record 26 of Set 10 | shortandy
# Processing Record 27 of Set 10 | shache
# Processing Record 28 of Set 10 | black river
# Processing Record 29 of Set 10 | barra do corda
# Processing Record 30 of Set 10 | al ghayzah
# Processing Record 31 of Set 10 | ancud
# Processing Record 32 of Set 10 | terbanggi besar
# Processing Record 33 of Set 10 | petukhovo
# Processing Record 34 of Set 10 | flin flon
# Processing Record 35 of Set 10 | magistral'nyy
# Processing Record 36 of Set 10 | beau vallon
# Processing Record 37 of Set 10 | fortuna
# Processing Record 38 of Set 10 | edea
# Processing Record 39 of Set 10 | lycksele
# Processing Record 40 of Set 10 | alo
# Processing Record 41 of Set 10 | port pirie
# Processing Record 42 of Set 10 | mahina
# Processing Record 43 of Set 10 | freetown
# Processing Record 44 of Set 10 | ola
# Processing Record 45 of Set 10 | yung shue wan
# Processing Record 46 of Set 10 | tahoua
# Processing Record 47 of Set 10 | sadjoavato
# City not found. Skipping...
# Processing Record 48 of Set 10 | lebu
# Processing Record 49 of Set 10 | erenhot
# Processing Record 50 of Set 10 | limassol
# Processing Record 1 of Set 11 | mokhsogollokh
# Processing Record 2 of Set 11 | zambezi
# Processing Record 3 of Set 11 | pecos
# Processing Record 4 of Set 11 | weno
# Processing Record 5 of Set 11 | sanctuary point
# Processing Record 6 of Set 11 | toga village
# City not found. Skipping...
# Processing Record 7 of Set 11 | callao
# Processing Record 8 of Set 11 | oamaru
# Processing Record 9 of Set 11 | santana
# Processing Record 10 of Set 11 | severo-yeniseyskiy
# Processing Record 11 of Set 11 | trumann
# Processing Record 12 of Set 11 | pangkalpinang
# Processing Record 13 of Set 11 | sagua de tanamo
# Processing Record 14 of Set 11 | wodonga
# Processing Record 15 of Set 11 | odienne
# Processing Record 16 of Set 11 | hannibal
# Processing Record 17 of Set 11 | vorkuta
# Processing Record 18 of Set 11 | kalmunai
# Processing Record 19 of Set 11 | jambusar
# Processing Record 20 of Set 11 | krasnyy chikoy
# Processing Record 21 of Set 11 | tambopata
# Processing Record 22 of Set 11 | barranca
# Processing Record 23 of Set 11 | qamdo
# Processing Record 24 of Set 11 | yangon
# Processing Record 25 of Set 11 | onega
# Processing Record 26 of Set 11 | hauterive
# Processing Record 27 of Set 11 | katsuren-haebaru
# Processing Record 28 of Set 11 | al khawr
# Processing Record 29 of Set 11 | quirinopolis
# Processing Record 30 of Set 11 | opuwo
# Processing Record 31 of Set 11 | yuzhno-kurilsk
# Processing Record 32 of Set 11 | kartaly
# Processing Record 33 of Set 11 | nambucca
# Processing Record 34 of Set 11 | kondoa
# Processing Record 35 of Set 11 | malmesbury
# Processing Record 36 of Set 11 | mapimi
# Processing Record 37 of Set 11 | baise city
# Processing Record 38 of Set 11 | lanzhou
# Processing Record 39 of Set 11 | isangel
# Processing Record 40 of Set 11 | shizuishan
# Processing Record 41 of Set 11 | lindsdal
# Processing Record 42 of Set 11 | chiavenna
# Processing Record 43 of Set 11 | buri
# Processing Record 44 of Set 11 | saveh
# Processing Record 45 of Set 11 | greymouth
# Processing Record 46 of Set 11 | tandur
# Processing Record 47 of Set 11 | dubbo
# Processing Record 48 of Set 11 | tokmok
# Processing Record 49 of Set 11 | isabela
# Processing Record 50 of Set 11 | flying fish cove
# Processing Record 1 of Set 12 | petropavlovsk-kamchatsky
# Processing Record 2 of Set 12 | stjordalshalsen
# Processing Record 3 of Set 12 | sao vicente
# Processing Record 4 of Set 12 | holualoa
# Processing Record 5 of Set 12 | old town
# Processing Record 6 of Set 12 | djibo
# Processing Record 7 of Set 12 | kingaroy
# Processing Record 8 of Set 12 | katsuura
# Processing Record 9 of Set 12 | ghanzi
# Processing Record 10 of Set 12 | dhulia
# Processing Record 11 of Set 12 | ceelbuur
# Processing Record 12 of Set 12 | guasdualito
# Processing Record 13 of Set 12 | bayanhongor
# Processing Record 14 of Set 12 | faya-largeau
# Processing Record 15 of Set 12 | tuy hoa
# Processing Record 16 of Set 12 | skopin
# Processing Record 17 of Set 12 | holguin
# Processing Record 18 of Set 12 | al kharijah
# Processing Record 19 of Set 12 | sinjai
# Processing Record 20 of Set 12 | brokopondo
# Processing Record 21 of Set 12 | jingdezhen
# Processing Record 22 of Set 12 | meulaboh
# Processing Record 23 of Set 12 | goundi
# Processing Record 24 of Set 12 | chernyshevsk
# Processing Record 25 of Set 12 | kyakhta
# Processing Record 26 of Set 12 | ulanhot
# Processing Record 27 of Set 12 | ewo
# Processing Record 28 of Set 12 | sokhumi
# Processing Record 29 of Set 12 | neelankarai
# Processing Record 30 of Set 12 | terrace
# Processing Record 31 of Set 12 | eirunepe
# Processing Record 32 of Set 12 | kamyshlov
# Processing Record 33 of Set 12 | aweil
# Processing Record 34 of Set 12 | port-vila
# Processing Record 35 of Set 12 | tifton
# Processing Record 36 of Set 12 | arrecife
# Processing Record 37 of Set 12 | san felipe
# Processing Record 38 of Set 12 | basco
# Processing Record 39 of Set 12 | tralee
# Processing Record 40 of Set 12 | kalkaman
# Processing Record 41 of Set 12 | lavras
# Processing Record 42 of Set 12 | albertville
# Processing Record 43 of Set 12 | wenling
# Processing Record 44 of Set 12 | usinsk
# Processing Record 45 of Set 12 | nova xavantina
# Processing Record 46 of Set 12 | joshimath
# Processing Record 47 of Set 12 | berezovyy
# Processing Record 48 of Set 12 | carutapera
# Processing Record 49 of Set 12 | camana
# Processing Record 50 of Set 12 | figuig (centre)
# Processing Record 1 of Set 13 | vorgashor
# Processing Record 2 of Set 13 | pont-l'abbe
# City not found. Skipping...
# Processing Record 3 of Set 13 | brisas de zicatela
# Processing Record 4 of Set 13 | peniche
# Processing Record 5 of Set 13 | kolonia
# Processing Record 6 of Set 13 | dakhla
# Processing Record 7 of Set 13 | coquimbo
# Processing Record 8 of Set 13 | talakan
# Processing Record 9 of Set 13 | linfen
# Processing Record 10 of Set 13 | le port
# Processing Record 11 of Set 13 | idfu
# Processing Record 12 of Set 13 | dampit
# Processing Record 13 of Set 13 | shenjiamen
# Processing Record 14 of Set 13 | zouerate
# Processing Record 15 of Set 13 | thames
# Processing Record 16 of Set 13 | kudahuvadhoo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          588
# Lat           588
# Lng           588
# Max Temp      588
# Humidity      588
# Cloudiness    588
# Wind Speed    588
# Country       588
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          jamestown  42.0970  -79.2353     16.77        36           0
# 1       san patricio  28.0170  -97.5169     28.28        78         100
# 2           waitangi -43.9535 -176.5597     16.01        96         100
# 3          grytviken -54.2811  -36.5092      0.80        93         100
# 4  port-aux-francais -49.3500   70.2167      5.47        96          99
#
#    Wind Speed Country
# 0        6.17      US
# 1        3.91      US
# 2        7.15      NZ
# 3        1.95      GS
# 4       12.74      TF

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv('../output_data/cities.csv', index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                jamestown  42.0970  -79.2353     16.77        36           0
# 1             san patricio  28.0170  -97.5169     28.28        78         100
# 2                 waitangi -43.9535 -176.5597     16.01        96         100
# 3                grytviken -54.2811  -36.5092      0.80        93         100
# 4        port-aux-francais -49.3500   70.2167      5.47        96          99
#
#          Wind Speed Country
# City_ID
# 0              6.17      US
# 1              3.91      US
# 2              7.15      NZ
# 3              1.95      GS
# 4             12.74      TF

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
    
    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
index13=city_data_df.loc[13]
index13
# Out:
# City          adamstown
# Lat             -25.066
# Lng           -130.1015
# Max Temp          21.74
# Humidity             53
# Cloudiness           80
# Wind Speed         4.96
# Country              PN
# Name: 13, dtype: object

# %%
city_data_df['Lat']>=0
# Out:
# City_ID
# 0       True
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 583    False
# 584     True
# 585     True
# 586    False
# 587     True
# Name: Lat, Length: 588, dtype: bool

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]

# Display sample data
northern_hemi_df.head()
# Out:
#                           City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                    jamestown  42.0970  -79.2353     16.77        36
# 1                 san patricio  28.0170  -97.5169     28.28        78
# 6                        tiksi  71.6872  128.8694      0.60        86
# 7                     mil'kovo  55.6078   37.7956      9.63        56
# 8        santa eularia des riu  38.9846    1.5341     21.84        72
#
#          Cloudiness  Wind Speed Country
# City_ID
# 0                 0        6.17      US
# 1               100        3.91      US
# 6                90       13.13      RU
# 7                37        2.08      RU
# 8                 0        1.54      ES

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2                 waitangi -43.9535 -176.5597     16.01        96         100
# 3                grytviken -54.2811  -36.5092      0.80        93         100
# 4        port-aux-francais -49.3500   70.2167      5.47        96          99
# 5                 linhares -19.3911  -40.0722     24.61        70          61
# 11                  kilosa  -6.8333   36.9833     19.32        93          22
#
#          Wind Speed Country
# City_ID
# 2              7.15      NZ
# 3              1.95      GS
# 4             12.74      TF
# 5              3.10      BR
# 11             1.07      TZ

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values,'Linear Regression on the Northern Hemisphere \nfor Maximum Temperature', 'Max Temp',(10,20))

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values,'Linear Regression on the Southern Hemisphere \nfor Maximum Temperature', 'Max Temp',(-50,90))

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values,'Linear Regression on the Northern Hemisphere \nfor % Humidity', '% Humidity',(45,5))

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values,'Linear Regression on the Southern Hemisphere \nfor % Humidity', '% Humidity',(-55,10))

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values,'Linear Regression on the Northern Hemisphere \nfor % Cloudiness', '% Cloudiness',(5,55))

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values,'Linear Regression on the Southern Hemisphere \nfor % Cloudiness', '% Cloudiness',(-55,12))

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values,'Linear Regression on the Northern Hemisphere \nfor Wind Speed', 'Wind Speed',(10,27))

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values,'Linear Regression on the Southern Hemisphere \nfor Wind Speed', 'Wind Speed',(-50,22))

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
